# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
jetbrains_products_stats_path = r"C:\Users\xperi\Desktop\Data Science\Skillbox. Курс Data Science\1.3 Типичная задача аналитика\Материалы\Типичная задача аналитика.xlsx"

# %%
jetbrains_products_stats = pd.read_excel(jetbrains_products_stats_path, 'Сырые данные')

# %%
jetbrains_products_stats.loc[jetbrains_products_stats['Контекст: место вызова'] == 'Панель инструментов']
# Out:
#                      Время      Пользователь    Действие  \
# 1      2019-08-21 00:59:03  DPU8XVBKJOXH6RB9   Запустить
# 2      2019-08-21 00:59:09  DPU8XVBKJOXH6RB9   Запустить
# 4      2019-08-21 01:00:17  DPU8XVBKJOXH6RB9   Запустить
# 5      2019-08-21 01:00:33  DPU8XVBKJOXH6RB9   Запустить
# 6      2019-08-21 01:00:40  DPU8XVBKJOXH6RB9   Запустить
# ...                    ...               ...         ...
# 103548 2019-09-17 21:49:11  8CIU8WIAB7BJCWR6       Назад
# 103549 2019-09-17 21:53:00  U36S7IZY66O23UQT   Запустить
# 103550 2019-09-17 21:53:50  U36S7IZY66O23UQT   Запустить
# 103553 2019-09-17 21:58:52  U36S7IZY66O23UQT   Запустить
# 103558 2019-09-17 22:07:01  67AG0F1DKRIPHLFQ  Остановить
#
#        Контекст: место вызова Контекст: версия продукта
# 1         Панель инструментов      PyCharm Professional
# 2         Панель инструментов      PyCharm Professional
# 4         Панель инструментов      PyCharm Professional
# ...
